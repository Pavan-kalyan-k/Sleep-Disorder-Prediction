# %%
data={
    'Model':["SVM","KNN","Decison","Logistic"],
    'Train (Accuracy)':[55,90,93,89],
    'Test':[51,89,89,91],
    'Precision':[69,86,86,90],
    'Re-Call':[56,86,85,88],
    'f1-score':[50,86,85,89],
    'ROC-AUC':[68,91,88,87],
    'CV-Score':[62,86,86,88],
    'std':[8,3.8,2.07,4.0]
}

# %%
import pandas as pd
model_selection = pd.DataFrame(data)

# %%
model_selection
# Out:
#       Model  Train (Accuracy)  Test  Precision  Re-Call  f1-score  ROC-AUC  \
# 0       SVM                55    51         69       56        50       68
# 1       KNN                90    89         86       86        86       91
# 2   Decison                93    89         86       85        85       88
# 3  Logistic                89    91         90       88        89       87
#
#    CV-Score   std
# 0        62  8.00
# 1        86  3.80
# 2        86  2.07
# 3        88  4.00

# %%
model_selection['Rank']=[4,2,3,1]

# %%
model_selection
# Out:
#       Model  Train (Accuracy)  Test  Precision  Re-Call  f1-score  ROC-AUC  \
# 0       SVM                55    51         69       56        50       68
# 1       KNN                90    89         86       86        86       91
# 2   Decison                93    89         86       85        85       88
# 3  Logistic                89    91         90       88        89       87
#
#    CV-Score   std  Rank
# 0        62  8.00     4
# 1        86  3.80     2
# 2        86  2.07     3
# 3        88  4.00     1

# %%
selected=model_selection.sort_values(by='Rank').head(2)
selected
# Out:
#       Model  Train (Accuracy)  Test  Precision  Re-Call  f1-score  ROC-AUC  \
# 3  Logistic                89    91         90       88        89       87
# 1       KNN                90    89         86       86        86       91
#
#    CV-Score  std  Rank
# 3        88  4.0     1
# 1        86  3.8     2

# %%
new_df = pd.DataFrame({
    'Model': ['logistic-h1','logistic-h2','KNN-h1','KNN-h2','logistic-h3'],
    'Train (Accuracy)': [92,92,93,93,],
    'Test': [93,93,91,80],
    'Precision': [94,94,88,77],
    'Re-Call': [89,89,87,80],
    'f1-score': [91,91,87,78],
    'ROC-AUC':[87,87,91,91],
    'CV-Score':[91,91,86,87],
    'std':[3.6,3.6,2.8,2.8]

})

df = pd.concat([selected, new_df], ignore_index=True)

# %%
df
# Out:
#          Model  Train (Accuracy)  Test  Precision  Re-Call  f1-score  ROC-AUC  \
# 0     Logistic                89    91         90       88        89       87
# 1          KNN                90    89         86       86        86       91
# 2  logistic-h1                92    93         94       89        91       87
# 3  logistic-h2                92    93         94       89        91       87
# 4       KNN-h1                93    91         88       87        87       91
# 5       KNN-h2                93    80         77       80        78       91
#
#    CV-Score  std  Rank
# 0        88  4.0   1.0
# 1        86  3.8   2.0
# 2        91  3.6   NaN
# 3        91  3.6   NaN
# 4        86  2.8   NaN
# 5        87  2.8   NaN

# %% [markdown]
# H1 logistic is the best model
